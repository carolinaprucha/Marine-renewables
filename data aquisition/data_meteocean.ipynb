# %%
import sys
# !{sys.executable} -m pip install metocean-api
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.0 MB 12.7 MB/s eta 0:00:01
#    --- ------------------------------------ 1.0/11.0 MB 12.7 MB/s eta 0:00:01
#    --------- ------------------------------ 2.6/11.0 MB 3.9 MB/s eta 0:00:03
#    ------------------- -------------------- 5.2/11.0 MB 6.1 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.0 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 7.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ---------------- ----------------------- 2.6/6.3 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 13.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 12.1 MB/s eta 0:00:00
# ...

# %%
from metocean_api import ts

# ECHOWAVE — wave data for Sines, Portugal
df_wave = ts.TimeSeries(
    lon=-9.01453,
    lat=37.74838,
    start_time='2010-01-01',
    end_time='2020-12-31',
    product='ECHOWAVE'
)
df_wave.import_data(save_csv=True)
print(df_wave.data.head())
# Out:
#   0%|          | 0/132 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Carolina\tudelft-conda\Lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File c:\Users\Carolina\tudelft-conda\Lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('https://opendap.4tu.nl/thredds/dodsC/data2/djht/f359cd0f-d135-416c-9118-e79dccba57b9/1/2010/TU-MREL_EU_ATL-2M_201001.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '5b293d36-1b83-4862-be8b-c3fcfeabd7b2']
#
# ...
